# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from train import main, load_model_and_evaluate
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import gym
from gym.envs.registration import register
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from networks import ReplayMemory, DQN, Transition
from env_pendulum import PendulumEnv

is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
register(
    id='Pendulum-v0',
    entry_point='env_pendulum:PendulumEnv',
    max_episode_steps=300)
env = gym.make('Pendulum-v0')
# Out:
# /Users/kevinb/anaconda3/lib/python3.10/site-packages/gym/envs/registration.py:498: UserWarning: WARN: Overriding environment Pendulum-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/kevinb/anaconda3/lib/python3.10/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Pendulum-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
env.action_space
# Out:
# Box(-2.0, 2.0, (1,), float32)

# %%
env.reward_range
# Out:
# (-inf, inf)

# %%
env.observation_space
# Out:
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)

# %%
main()
# Out:
# Complete

# %%
load_model_and_evaluate('policy_net_final_task.pth')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 load_model_and_evaluate('policy_net_final_task.pth')
#
# File ~/Desktop/GaoUCSD/Simple_CL_Env/train.py:164, in load_model_and_evaluate(path, device)
#     161 state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
#     163 for t in count():
# --> 164     env.render()
#     166 with torch.no_grad():
#     167     action = select_action(state)
#
# File ~/Desktop/GaoUCSD/Simple_CL_Env/env_pendulum.py:253, in PendulumEnv.render(self)
#     251 if self.render_mode == "human":
#     252     pygame.event.pump()
# --> 253     self.clock.tick(self.metadata["render_fps"])
#     254     pygame.display.flip()
#     256 else:  # mode == "rgb_array":
#
# KeyboardInterrupt:
